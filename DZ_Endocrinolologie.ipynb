# %% [markdown]
# <a href="https://colab.research.google.com/github/arnautoleg/Endocrinology/blob/main/DZ_Endocrinolologie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Connect to google drive to save images

# %%
from google.colab import drive
drive.mount('/content/drive')

# Set the DPI for high resolution (e.g., 300)
dpi = 300
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %% [markdown]
# #DataFrame

# %%
#df = pd.read_excel('/content/Studiul epidemiologic al patologiilor endocrine (Ответы) (2) (Восстановленный).xlsx')
file_path = 'https://github.com/arnautoleg/Endocrinology/raw/main/DZ%2022.09.2023.xlsx'

df = pd.read_excel(file_path, engine='openpyxl')

#https://github.com/arnautoleg/Endocrinology/blob/main/DZ%2022.09.2023.xlsx

# %%
df.columns
# Out:
# Index(['Отметка времени', 'ID', 'Denumirea localității',
#        'Denumirea raionului/municipiului', 'Data completării chestionarului',
#        'Anul nașterii, luna, data', 'Virsta, anii', 'Sexul',
#        'Educația (ultimul nivel de educatie finalizat)', 'Starea civila',
#        ...
#        'Laborator', 'Risc cardiovascular', 'Risc CV global usor',
#        'Risc CV global moderat', 'Risc CV global crescut',
#        'Risc CV foarte crescut', 'Mediu de trai', 'Score 2       scazut',
#        'Score 2  moderat', 'Score 2 crescut'],
#       dtype='object', length=103)

# %%
df[df.Sexul.isna()]
# Out:
# Empty DataFrame
# Columns: [Отметка времени, ID, Denumirea localității, Denumirea raionului/municipiului, Data completării chestionarului, Anul nașterii, luna, data, Virsta, anii, Sexul, Educația (ultimul nivel de educatie finalizat), Starea civila, Grup etnic , Ocupaţia (guvernam) de bază din ultimele 12 luni? [Angajat în sectorul guvernamental], Ocupaţia (non guvvern de bază din ultimele 12 luni? [Angajat în sectorul non-guvernamental sau privat], Ocupaţia (cont propr) de bază din ultimele 12 luni? [Angajat pe cont propriu], Ocupaţia (student) de bază din ultimele 12 luni? [Student], Ocupaţia (casnic) de bază din ultimele 12 luni? [Casnic/casnică], Ocupaţia (pensionar) de bază din ultimele 12 luni? [Pensionar], Ocupaţia (apt) de bază din ultimele 12 luni? [Neangajat în câmpul muncii (apt de muncă)], Ocupaţia (inapt) de bază din ultimele 12 luni? [Neangajat în câmpul muncii (inapt de muncă)], Ocupaţia (refuz) de bază din ultimele 12 luni? [Refuz], Care sunt veniturile medii lunare (MDL) ale gospodăriei DVS în ultimele 12 luni?, Modul de viață, Fumatul, Fumatul  _ Câți ani*țigarete pe zi, Rudele de gradul 1 [Diabet zaharat], Rudele de gradul 1 [HTA], Rudele de gradul 1 [Obesitatea], Rudele de gradul 1 [Dislipidemie], Rudele de gradul 1 [Patologia glandei tiroide], Rudele de gradul 2 [Diabet zaharat], Rudele de gradul 2 [HTA], Rudele de gradul 2 [Obesitatea], Rudele de gradul 2 [Dislipidemie], Rudele de gradul 2 [Patologia glandei tiroide], Istotia personala [Diabet zaharat], Istotia personala [HTA], Istotia personala [Obesitatea], Istotia personala [Dislipidemie], Istotia personala [Patologia glandei tiroide], Tratamentul curent  (Medicamente folosite actualmente), Covid, Numarul de copii (intrebare pentru femei), Numarul de copii cu masa corporala peste 4 kg la nastere (intrebare pentru femei), De câte ori pe zi mâncați?, Într-o săptămână tipică, în câte zile mâncaţi fructe? (Numarul de zile), Câte porţii de fructe mâncaţi pe parcursul unei din aceste zile? (Numărul de porții), Într-o săptămână tipică, în câte zile mâncaţi legume (cu excepţia cartofilor)?Numărul de zile, Câte porţii de legume (cu excepţia cartofilor) mâncaţi pe parcursul unei din aceste zile? Numărul de porții, De câte ori pe săptămână consumați cereale?, De câte ori pe săptămână consumați cartofi?, Câte bucăți de pîine consumați pe zi?, De câte ori pe săptămână consumați turte, chifle, gofre?, Talia, cm, Greutatea, kg, IMC, Circumferinta abdominala, cm (CA), Circumferinta Șoldului, cm (CS), CA/CȘ, TA sist, TA diast, Glucoza bazală, Colesterol total, LDL-C, VLDL Colesterol, HDL-C, Trigliceride , Acid uric, Creatinina, HbA1C, TSH, AC/TPO, Ca, TOTG (a jeun), TOTG (peste 2 ore), HOMA, Hb, Eritrocite, Chestionar Findrisc (valoare), Chestionar Findrisc , Chestionar Anxietate (valoare), Chestionar Anxietate, Chestionar Depresie (valoare), Chestionar Depresie, Chestionar evaluarea Stresului (valoare), Chestionar evaluarea Stresului, Chestionar HADS: Depresia (valoare), Chestionar HADS: Depresia, Chestionar HADS: Anxietatea (valoare), Chestionar HADS: Anxietatea, Chestionar MMSE (disfuncții cognitive) valoarea, Chestionar MMSE (disfuncții cognitive), eGFR, Insulina, Laborator, Risc cardiovascular, Risc CV global usor, Risc CV global moderat, Risc CV global crescut, Risc CV foarte crescut, Mediu de trai, ...]
# Index: []
#
# [0 rows x 103 columns]

# %%
df.drop(['Отметка времени', 'ID', 'Denumirea localității',
        'Denumirea raionului/municipiului', 'Data completării chestionarului',
         'Anul nașterii, luna, data'], axis=1, inplace=True) # removed 'Nume, prenume', repository is open

# %%
print(df.shape)
df.dropna(how='all', inplace=True)   #to drop if all values in the row are nan
print(df.shape)
# Out:
# (1020, 97)
# (1020, 97)

# %%
df.columns
# Out:
# Index(['Virsta, anii', 'Sexul',
#        'Educația (ultimul nivel de educatie finalizat)', 'Starea civila',
#        'Grup etnic ',
#        'Ocupaţia (guvernam) de bază din ultimele 12 luni? [Angajat în sectorul guvernamental]',
#        'Ocupaţia (non guvvern de bază din ultimele 12 luni? [Angajat în sectorul non-guvernamental sau privat]',
#        'Ocupaţia (cont propr) de bază din ultimele 12 luni? [Angajat pe cont propriu]',
#        'Ocupaţia (student) de bază din ultimele 12 luni? [Student]',
#        'Ocupaţia (casnic) de bază din ultimele 12 luni? [Casnic/casnică]',
#        'Ocupaţia (pensionar) de bază din ultimele 12 luni? [Pensionar]',
#        'Ocupaţia (apt) de bază din ultimele 12 luni? [Neangajat în câmpul muncii (apt de muncă)]',
#        'Ocupaţia (inapt) de bază din ultimele 12 luni? [Neangajat în câmpul muncii (inapt de muncă)]',
#        'Ocupaţia (refuz) de bază din ultimele 12 luni? [Refuz]',
#        'Care sunt veniturile medii lunare (MDL) ale gospodăriei DVS în ultimele 12 luni?',
#        'Modul de viață', 'Fumatul', 'Fumatul  _ Câți ani*țigarete pe zi',
#        'Rudele de gradul 1 [Diabet zaharat]', 'Rudele de gradul 1 [HTA]',
#        'Rudele de gradul 1 [Obesitatea]', 'Rudele de gradul 1 [Dislipidemie]',
#        'Rudele de gradul 1 [Patologia glandei tiroide]',
#        'Rudele de gradul 2 [Diabet zaharat]', 'Rudele de gradul 2 [HTA]',
#        'Rudele de gradul 2 [Obesitatea]', 'Rudele de gradul 2 [Dislipidemie]',
#        'Rudele de gradul 2 [Patologia glandei tiroide]',
#        'Istotia personala [Diabet zaharat]', 'Istotia personala [HTA]',
#        'Istotia personala [Obesitatea]', 'Istotia personala [Dislipidemie]',
#        'Istotia personala [Patologia glandei tiroide]',
#        'Tratamentul curent  (Medicamente folosite actualmente)', 'Covid',
#        'Numarul de copii (intrebare pentru femei)',
#        'Numarul de copii cu masa corporala peste 4 kg la nastere (intrebare pentru femei)',
#        'De câte ori pe zi mâncați?',
#        'Într-o săptămână tipică, în câte zile mâncaţi fructe? (Numarul de zile)',
#        'Câte porţii de fructe mâncaţi pe parcursul unei din aceste zile? (Numărul de porții)',
#        'Într-o săptămână tipică, în câte zile mâncaţi legume (cu excepţia cartofilor)?Numărul de zile',
#        'Câte porţii de legume (cu excepţia cartofilor) mâncaţi pe parcursul unei din aceste zile? Numărul de porții',
#        'De câte ori pe săptămână consumați cereale?',
#        'De câte ori pe săptămână consumați cartofi?',
#        'Câte bucăți de pîine consumați pe zi?',
#        'De câte ori pe săptămână consumați turte, chifle, gofre?', 'Talia, cm',
#        'Greutatea, kg', 'IMC', 'Circumferinta abdominala, cm (CA)',
#        'Circumferinta Șoldului, cm (CS)', 'CA/CȘ', 'TA sist', 'TA diast',
#        'Glucoza bazală', 'Colesterol total', 'LDL-C', 'VLDL Colesterol',
#        'HDL-C', 'Trigliceride ', 'Acid uric', 'Creatinina', 'HbA1C', 'TSH',
#        'AC/TPO', 'Ca', 'TOTG (a jeun)', 'TOTG (peste 2 ore)', 'HOMA', 'Hb',
#        'Eritrocite', 'Chestionar Findrisc (valoare)', 'Chestionar Findrisc ',
#        'Chestionar Anxietate (valoare)', 'Chestionar Anxietate',
#        'Chestionar Depresie (valoare)', 'Chestionar Depresie',
#        'Chestionar evaluarea Stresului (valoare)',
#        'Chestionar evaluarea Stresului', 'Chestionar HADS: Depresia (valoare)',
#        'Chestionar HADS: Depresia', 'Chestionar HADS: Anxietatea (valoare)',
#        'Chestionar HADS: Anxietatea',
#        'Chestionar MMSE (disfuncții cognitive) valoarea',
#        'Chestionar MMSE (disfuncții cognitive)', 'eGFR', 'Insulina',
#        'Laborator', 'Risc cardiovascular', 'Risc CV global usor',
#        'Risc CV global moderat', 'Risc CV global crescut',
#        'Risc CV foarte crescut', 'Mediu de trai', 'Score 2       scazut',
#        'Score 2  moderat', 'Score 2 crescut'],
#       dtype='object')

# %% [markdown]
# #Aging by sex

# %%
print(df.Sexul.unique())
df.Sexul = df.Sexul.str.upper()
print(df.Sexul.unique())
# Out:
# ['F' 'B' 'b' 'f']
# ['F' 'B']

# %%
df['Virsta, anii'].isna().sum()
# Out:
# 0

# %%
round(df['Virsta, anii'].describe(), 1)
# Out:
# count    1020.0
# mean       49.0
# std        12.9
# min        14.0
# 25%        39.0
# 50%        49.0
# 75%        59.0
# max        85.0
# Name: Virsta, anii, dtype: float64

# %%
round(df.groupby(by='Sexul')['Virsta, anii'].describe().T, 1)
# Out:
# Sexul      B      F
# count  343.0  677.0
# mean    52.1   47.4
# std     13.3   12.5
# min     14.0   17.0
# 25%     43.0   38.0
# 50%     53.0   46.0
# 75%     62.0   58.0
# max     85.0   79.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def histogram_u (df, var, bins):
  sns.set_palette("deep")
  sns.histplot(data=df,
               x=var,
               binwidth=1, bins=bins)
  plt.grid(False)
  file_path = f'/content/drive/MyDrive/DZ_endocrinologie/{var}'

  plt.savefig(file_path, dpi=dpi)
  plt.show()

histogram_u (df, 'Virsta, anii', 10)

# %%
import seaborn as sns
import pandas as pd

def bar_u (df, var):
  sns.set(style="whitegrid")  # Optional: Set a style for the plot
  sns.countplot(x=var, data=df)
  plt.xlabel(var)
  plt.ylabel('Proportion')
  plt.title(f'{var} Distribution')
  file_path = f'/content/drive/MyDrive/DZ_endocrinologie/{var}_abs'
  plt.savefig(file_path, dpi=dpi)
  plt.show()

bar_u (df, 'Sexul')

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Calculate proportions
gender_proportions = df['Sexul'].value_counts(normalize=True) * 100  # Multiply by 100 to get percentages

# Create a bar plot with proportions using Seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(6, 4))  # Optional: Set the figure size
ax = sns.barplot(x=gender_proportions.index, y=gender_proportions.values, palette="viridis")
ax.set(ylabel="Percentage", title="Gender Distribution")



# Display percentages on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center')

plt.ylim(0, 100)

file_path = f'/content/drive/MyDrive/DZ_endocrinologie/Sexul'
plt.savefig(file_path, dpi=dpi)

plt.show()

# %%
for cat in df.Sexul.unique():
  print(cat)
# Out:
# F
# B

# %%
from scipy import stats

def histogram_m(df, var1, var2, bins):
  # Create a histogram using Seaborn
  ax = sns.histplot(data=df, x=var1, hue=var2, multiple="stack", bins=15)
  #plt.xlabel("Age (years)")
  plt.title(f"{var1} Distribution by {var2}")

  group, number, list_ ='group', 1, []

  for cat in df[var2].unique():
    group=group+str(number)
    #print(group)
    list_.append([group, cat, df[df[var2] == cat][var1]])
    group=group[:-1]
    number+=1


  _, p_value = stats.mannwhitneyu(list_[0][2], list_[1][2], alternative='two-sided')

  # Display the p-value on the plot
  plt.text(
      x=30,  # X-coordinate of the annotation (adjust as needed)
      y=140,   # Y-coordinate of the annotation (adjust as needed)
      s=f'Mann-Whitney U = {_} \n p-value: {p_value:.4f}',  # Text to display
      ha='center',   # Horizontal alignment
      va='bottom',   # Vertical alignment
      fontsize=10,   # Font size
      color='black'  # Text color
  )

  file_path = f'/content/drive/MyDrive/DZ_endocrinologie/{var1}-{var2}'
  plt.savefig(file_path, dpi=dpi)

  plt.show()

histogram_m(df, var1="Virsta, anii", var2="Sexul", bins=20)

# %% [markdown]
# #Aging sex BMI

# %%
df.IMC.isna().sum()
# Out:
# 1018

# %%
import numpy as np

df['Talia, cm'].unique()
df['Talia, cm'].replace(['1.65', '1.55', '1.60', '1.59', '1.78', '1.73', '1.82', '-', '?'],
           [165, 155, 160, 159, 178, 173, 182, np.NaN, np.NaN], inplace=True)
df['Talia, cm'].unique()
# Out:
# array([162., 178., 170., 156., 164., 167., 158., 152., 176., 160., 185.,
#        151., 165., 188., 180., 163., 168., 172., 171., 166., 174., 182.,
#        190., 179., 157., 187., 186., 196., 175., 110., 154., 189., 184.,
#        173., 169., 181., 159., 155., 150., 177., 153., 192., 183., 161.,
#        146., 140., 145., 194., 191., 149., 143.,  nan, 147., 148.])

# %%
df['Greutatea, kg'].unique()
# Out:
# array([106. ,  96. ,  90. ,  92. ,  95. ,  75. ,  88. ,  73. , 101. ,
#         65. , 110. ,  74. ,  78. ,  55. ,  64. ,  72. , 118. ,  85. ,
#         83. ,  69. , 102. ,  80. ,  94. ,  84. ,  98. ,  86. ,  77. ,
#         59. , 100. ,  87. ,  70. ,  68. ,  71. ,  62. ,  99. ,  58. ,
#        128. ,  67. ,  47. ,  60. ,  81. ,  95.2,  82. ,  76.4, 113.2,
#         79. ,  91. ,  76. ,  97. ,  71.2,  81.5,  83.8,  41.5, 131. ,
#         76.8,  89. , 112. , 123. ,  66. ,  63. , 135. ,  57. ,  52. ,
#         50. , 103. ,  46.5, 107. ,  93. , 115. ,  56. ,  61. ,  48. ,
#         46. ,  44. ,  45. ,  53. ,  54. , 120. , 124. , 159.7, 116. ,
#         40. ,  63.3, 108. ,  94.4, 105. , 140. ,  51. ,  61.5, 104. ,
#         71.5, 109. , 130. ,  49. , 125. ,  65.3,  85.7, 122. ,  74.1,
#         61.7,  93.8,  80.2,  41. ,  66.6,  84.3,  60.9,  81.3,  68.3,
#         63.8,  58.9,  93.2,  58.2,  85.5,  66.9, 127. ,  78.9,  68.2,
#         62.1,  58.5,  60.6,  78.5,  63.7,  78.8,  69.1,  79.4,  73.7,
#         60.3,  73.2, 126.4,  61.8,  98.1,  61.2,  74.3, 106.2, 105.3,
#         99.6,  73.3,  59.7,  93.9,  97.1, 111.9,  80.5, 125.2,  45.5,
#         89.9, 110.3,  92.5,  67.2,  85.1,  84.9,  86.1,  77.9,  91.8,
#         75.8,  66.5,  71.9,  92.6,  80.3,  70.2,  56.5,  96.3,  75.4,
#         64.4,  81.7,  70.9,  59.9,  91.1,  81.8,  80.7,  92.7,  79.7,
#         89.8,  67.7, 102.8,  58.6,  66.8,  72.1, 108.5, 103.3,  83.9,
#         93.3,  85.9,  68.1,  83.5, 116.4, 107.3,  96.7,  96.2,  80.1,
#         68.6,  87.5,  70.4,  66.4,  67.3, 101.1,  85.2,  68.4,  69.5,
#         54.3,  75.2,  57.9, 102.3,  83.4, 119.2,  67.8,  76.5,  79.2,
#         85.8,  77.1, 105.8,  86.6,  83.6,  71.8,  64.1,  77.4,  66.7,
#         92.8,  79.9,  86.5,  60.1, 127.1,  55.3,  86.9,   nan,  67.1,
#         62.5,  65.7,  64.8,  90.7,  70.8,  91.2,  69.8, 113.1,  56.4,
#         65.9,  69.3,  63.1,  49.2,  76.1,  89.7,  50.1,  94.1,  68.5,
#        122.2, 112.3,  82.4,  94.6,  77.7, 104.6,  82.6, 104.4,  93.6,
#        107.8,  76.9,  78.6,  54.6,  64.9, 121.1,  88.9,  97.8,  56.7,
#         70.3,  64.5,  73.4,  95.1,  95.9,  64.6,  55.5,  54.8,  55.1,
#         53.3, 101.6,  98.5,  97.7,  82.5, 100.9,  94.2, 110.1, 115.8,
#         78.2,  99.8, 114. , 132. , 108.2,  85.6, 121. , 101.4, 156. ,
#         86.7])

# %%
import datetime

df['Greutatea, kg'].unique()
df['Greutatea, kg'].replace(['-','?'], [np.NaN, np.NaN], inplace=True)
df['Greutatea, kg'] = pd.to_numeric(df['Greutatea, kg'])
df['Greutatea, kg'].unique()
# Out:
# array([106. ,  96. ,  90. ,  92. ,  95. ,  75. ,  88. ,  73. , 101. ,
#         65. , 110. ,  74. ,  78. ,  55. ,  64. ,  72. , 118. ,  85. ,
#         83. ,  69. , 102. ,  80. ,  94. ,  84. ,  98. ,  86. ,  77. ,
#         59. , 100. ,  87. ,  70. ,  68. ,  71. ,  62. ,  99. ,  58. ,
#        128. ,  67. ,  47. ,  60. ,  81. ,  95.2,  82. ,  76.4, 113.2,
#         79. ,  91. ,  76. ,  97. ,  71.2,  81.5,  83.8,  41.5, 131. ,
#         76.8,  89. , 112. , 123. ,  66. ,  63. , 135. ,  57. ,  52. ,
#         50. , 103. ,  46.5, 107. ,  93. , 115. ,  56. ,  61. ,  48. ,
#         46. ,  44. ,  45. ,  53. ,  54. , 120. , 124. , 159.7, 116. ,
#         40. ,  63.3, 108. ,  94.4, 105. , 140. ,  51. ,  61.5, 104. ,
#         71.5, 109. , 130. ,  49. , 125. ,  65.3,  85.7, 122. ,  74.1,
#         61.7,  93.8,  80.2,  41. ,  66.6,  84.3,  60.9,  81.3,  68.3,
#         63.8,  58.9,  93.2,  58.2,  85.5,  66.9, 127. ,  78.9,  68.2,
#         62.1,  58.5,  60.6,  78.5,  63.7,  78.8,  69.1,  79.4,  73.7,
#         60.3,  73.2, 126.4,  61.8,  98.1,  61.2,  74.3, 106.2, 105.3,
#         99.6,  73.3,  59.7,  93.9,  97.1, 111.9,  80.5, 125.2,  45.5,
#         89.9, 110.3,  92.5,  67.2,  85.1,  84.9,  86.1,  77.9,  91.8,
#         75.8,  66.5,  71.9,  92.6,  80.3,  70.2,  56.5,  96.3,  75.4,
#         64.4,  81.7,  70.9,  59.9,  91.1,  81.8,  80.7,  92.7,  79.7,
#         89.8,  67.7, 102.8,  58.6,  66.8,  72.1, 108.5, 103.3,  83.9,
#         93.3,  85.9,  68.1,  83.5, 116.4, 107.3,  96.7,  96.2,  80.1,
#         68.6,  87.5,  70.4,  66.4,  67.3, 101.1,  85.2,  68.4,  69.5,
#         54.3,  75.2,  57.9, 102.3,  83.4, 119.2,  67.8,  76.5,  79.2,
#         85.8,  77.1, 105.8,  86.6,  83.6,  71.8,  64.1,  77.4,  66.7,
#         92.8,  79.9,  86.5,  60.1, 127.1,  55.3,  86.9,   nan,  67.1,
#         62.5,  65.7,  64.8,  90.7,  70.8,  91.2,  69.8, 113.1,  56.4,
#         65.9,  69.3,  63.1,  49.2,  76.1,  89.7,  50.1,  94.1,  68.5,
#        122.2, 112.3,  82.4,  94.6,  77.7, 104.6,  82.6, 104.4,  93.6,
#        107.8,  76.9,  78.6,  54.6,  64.9, 121.1,  88.9,  97.8,  56.7,
#         70.3,  64.5,  73.4,  95.1,  95.9,  64.6,  55.5,  54.8,  55.1,
#         53.3, 101.6,  98.5,  97.7,  82.5, 100.9,  94.2, 110.1, 115.8,
#         78.2,  99.8, 114. , 132. , 108.2,  85.6, 121. , 101.4, 156. ,
#         86.7])

# %%
df[df['Talia, cm'].isna()][['Talia, cm', 'Greutatea, kg']]
# Out:
#      Talia, cm  Greutatea, kg
# 822        NaN            NaN
# 917        NaN            NaN

# %%
df['IMC'] = df['Greutatea, kg']/(df['Talia, cm']/100)**2
df['IMC']
# Out:
# 0       40.390184
# 1       30.299205
# 2       31.141869
# 3       37.804076
# 4       32.871972
#           ...
# 1015    32.455678
# 1016    27.885187
# 1017    24.816327
# 1018    27.717685
# 1019    26.397977
# Name: IMC, Length: 1020, dtype: float64

# %%
round(df.groupby(by='Sexul')['IMC'].describe().T, 1)
# Out:
# Sexul      B      F
# count  341.0  677.0
# mean    29.3   28.3
# std      5.2    6.2
# min     14.7   15.6
# 25%     26.0   23.9
# 50%     28.9   27.3
# 75%     32.4   32.1
# max     45.7   66.1

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import spearmanr


# subset - which var we need to consider to remove NA
# x - x axis var
# y - y axis var
# h - color for var
# col - the var for
def scatter_2(subset, x, y, h, col):
  # Filter out rows with missing values
  df_cleaned = df.dropna(subset=subset)

  # Create a relplot using Seaborn
  g = sns.relplot(x=x, y=y, hue=h, col=col, data=df_cleaned, height=3.5, kind='scatter')

# Calculate Spearman's correlation coefficient and 95% CI
  for ax in g.axes.flat:
    data_subset = df_cleaned[df_cleaned[col] == ax.get_title()[-1]]  # Filter data for each subplot
    correlation, p_value = spearmanr(data_subset[x], data_subset[y])

    # Bootstrap to calculate 95% CI for the correlation
    np.random.seed(0)  # Set a random seed for reproducibility
    n_iterations = 1000  # Number of bootstrap iterations
    bootstrap_correlations = []

    for _ in range(n_iterations):
        # Resample the data with replacement
        resampled_data = data_subset.sample(len(data_subset), replace=True)
        resampled_correlation, _ = spearmanr(resampled_data[x], resampled_data[y])
        bootstrap_correlations.append(resampled_correlation)

    # Calculate 95% CI
    lower_ci = np.percentile(bootstrap_correlations, 2.5)
    upper_ci = np.percentile(bootstrap_correlations, 97.5)

    # Annotate the correlation with 95% CI
    ax.annotate(f"Spearman's ρ = {correlation:.2f}\n95% CI: [{lower_ci:.2f}, {upper_ci:.2f}]",
                xy=(0.5, 0.9), xycoords='axes fraction',
                fontsize=10, color='black', ha='right')

    # Add an interpolation line with 95% CI using sns.regplot
    sns.regplot(x=x, y=y, data=data_subset, ax=ax, scatter=False, color='black', ci=95)

  plt.ylim(0, df[y].max()+df[y].max()*0.1)
  file_path = f'/content/drive/MyDrive/DZ_endocrinologie/{x}-{y}-{h}'
  plt.savefig(file_path, dpi=dpi)
  plt.show()

scatter_2(subset=['Virsta, anii', 'IMC'], x='Virsta, anii', y='IMC', h='Sexul', col='Sexul')

# %% [markdown]
# #Varsta – sex – CA

# %%
df['Circumferinta abdominala, cm (CA)'].isna().sum()
# Out:
# 0

# %%
round(df.groupby(by='Sexul')['Circumferinta abdominala, cm (CA)'].describe().T, 1)
# Out:
# Sexul      B      F
# count  343.0  677.0
# mean   101.6   92.1
# std     13.1   15.6
# min     60.0   58.0
# 25%     94.0   80.0
# 50%    100.0   91.0
# 75%    110.0  102.0
# max    139.0  155.0

# %%
scatter_2(subset=['Virsta, anii', 'Circumferinta abdominala, cm (CA)'],
          x='Virsta, anii',
          y='Circumferinta abdominala, cm (CA)',
          h='Sexul', col='Sexul')

# %% [markdown]
# #Varsta – sex – CA/CȘ

# %%
df['CA/CȘ'] = df['Circumferinta abdominala, cm (CA)'] / df['Circumferinta Șoldului, cm (CS)']
df['CA/CȘ'].isna().sum()
df.rename(columns={"CA/CȘ": "CA_CȘ"}, errors="raise", inplace=True)

# %%
round(df.groupby(by='Sexul')['CA_CȘ'].describe().T, 1)
# Out:
# Sexul      B      F
# count  343.0  677.0
# mean     1.0    0.9
# std      0.1    0.1
# min      0.5    0.6
# 25%      0.9    0.8
# 50%      1.0    0.9
# 75%      1.0    0.9
# max      1.3    1.2

# %%
scatter_2(subset=['Virsta, anii', 'CA_CȘ'],
          x='Virsta, anii',
          y='CA_CȘ',
          h='Sexul', col='Sexul')

# %% [markdown]
# #Varsta – sex – glucoza + Virsta BMI Sex Diabetes status

# %%
df['Glucoza bazală'].unique()
# Out:
# array(['7.03', '5.34', '6.26', '5.62', '8.82', '4.65', '7.31', '5.29',
#        '5.82', '6.15', '6.02', '5.25', '5.66', '5.61', 8, '4.32', '4.71',
#        '4.59', '5.49', '5.02', '5.06', '4.9', '4.93', '5.43', '4.36',
#        '5.37', '4.72', '4.78', '4.27', '4.96', '5.03', '4.97', '4.7',
#        '5.78', '4.77', '7.5', '5.64', '6.2', '5.07', '4.54', '5.11',
#        '4.23', '4.85', '5.63', '5.58', '5.81', nan, '4.99', '5.3', '5.89',
#        '6.44', '5.56', '5.08', '5.47', '5.14', '4.64', '6.45', '4.69',
#        '4.19', '5.21', '4.81', 5, '6.43', '4.89', '4.18', '7.59', '4.76',
#        '4.98', '4.56', '6.05', '4.43', '5.15', '5.7', '4.91', '4.5',
#        '5.39', '4.37', '4.46', '4.57', '6.42', '4.95', '4.68', '4.67',
#        '5.75', '5.59', '5.97', '7.17', '5.09', '5.67', '4.74', '5.27',
#        '5.36', '4.75', '6.78', '6.56', '6.52', '4.86', '5.22', '4.07',
#        '5.35', '4.17', '5.41', '4.35', '4.94', '5.33', '4.41', '4.45',
#        '5.79', '6.35', '4.24', '4.55', '4.44', '4.62', '5.0', '4.84',
#        '4.92', '4.49', '4.47', '4.61', '4.21', 72, '5.26', '5.16', '3.83',
#        '4.66', '4.48', '5.31', '4.2', '4.38', '5.54', '8.05', '3.93',
#        '4.12', '4.58', '5.04', '5.4', '4.26', '4.31', '4.1', 5.15, '5.46',
#        '3.51', '6.06', '4.33', '4.83', '4.42', '4.13', '4.04', '5.1',
#        '6.1', '5.6', '5.2', '5.9', '6.4', '4.8', '4.4', '4.6', '5.8',
#        '5.5', '7.9', '4.3', '6.6', '7.4', '6.3', '6.0', '6.5', '6.8',
#        '8.2', '7.2', '4.0', '3.8', '3.9', '3.6', '4.79', '5.01', '4.34',
#        '4.39', '4.05', '6.64', '5.24', '6.7', '14.5', 5.7, '7.7', '8.0',
#        '7.0', '5.48', '5.45', datetime.datetime(2023, 7, 4, 0, 0),
#        datetime.datetime(2023, 1, 5, 0, 0),
#        datetime.datetime(2023, 4, 4, 0, 0),
#        datetime.datetime(2023, 8, 4, 0, 0),
#        datetime.datetime(2023, 9, 5, 0, 0),
#        datetime.datetime(2023, 5, 4, 0, 0),
#        datetime.datetime(2023, 7, 7, 0, 0),
#        datetime.datetime(2023, 3, 5, 0, 0),
#        datetime.datetime(2023, 6, 5, 0, 0),
#        datetime.datetime(2023, 5, 5, 0, 0),
#        datetime.datetime(2023, 4, 5, 0, 0),
#        datetime.datetime(2023, 9, 4, 0, 0),
#        datetime.datetime(2023, 7, 5, 0, 0),
#        datetime.datetime(2023, 3, 6, 0, 0),
#        datetime.datetime(2023, 2, 5, 0, 0),
#        datetime.datetime(2023, 8, 6, 0, 0),
#        datetime.datetime(2023, 6, 6, 0, 0),
#        datetime.datetime(2023, 6, 4, 0, 0),
#        datetime.datetime(2023, 1, 4, 0, 0),
#        datetime.datetime(2023, 2, 6, 0, 0),
#        datetime.datetime(2023, 1, 6, 0, 0), '5.40',
#        datetime.datetime(2023, 8, 5, 0, 0),
#        datetime.datetime(2023, 3, 4, 0, 0), 4,
#        datetime.datetime(2023, 2, 3, 0, 0), '5.76',
#        datetime.datetime(2023, 4, 7, 0, 0),
#        datetime.datetime(2023, 11, 4, 0, 0),
#        datetime.datetime(2023, 4, 11, 0, 0),
#        datetime.datetime(2023, 8, 8, 0, 0),
#        datetime.datetime(2023, 6, 8, 0, 0), 10.5,
#        datetime.datetime(2023, 5, 8, 0, 0),
#        datetime.datetime(2023, 8, 10, 0, 0),
#        datetime.datetime(2023, 9, 18, 0, 0),
#        datetime.datetime(2023, 4, 9, 0, 0),
#        datetime.datetime(2023, 1, 10, 0, 0),
#        datetime.datetime(2023, 3, 9, 0, 0),
#        datetime.datetime(2023, 6, 13, 0, 0),
#        datetime.datetime(2023, 5, 7, 0, 0),
#        datetime.datetime(2023, 2, 18, 0, 0), '14.77', '7.23', '10.29',
#        '6.51', datetime.datetime(2023, 6, 7, 0, 0), '7.53', '7.62',
#        '13.15', '5.99', '8.22', datetime.datetime(2023, 8, 11, 0, 0),
#        datetime.datetime(2023, 1, 8, 0, 0),
#        datetime.datetime(2023, 11, 6, 0, 0), '7.16',
#        datetime.datetime(2023, 12, 11, 0, 0), '8.83', '19.32', '9.51',
#        '13.56', '6.21', datetime.datetime(2023, 6, 3, 0, 0), '6.14',
#        datetime.datetime(2023, 4, 13, 0, 0),
#        datetime.datetime(2023, 7, 11, 0, 0),
#        datetime.datetime(2023, 9, 11, 0, 0), '5.23',
#        datetime.datetime(2023, 3, 12, 0, 0), '8.62', '7.78',
#        datetime.datetime(2023, 9, 8, 0, 0),
#        datetime.datetime(2023, 2, 9, 0, 0),
#        datetime.datetime(2023, 6, 15, 0, 0), '6.72',
#        datetime.datetime(2023, 4, 12, 0, 0), '7.69',
#        datetime.datetime(2023, 7, 8, 0, 0),
#        datetime.datetime(2023, 12, 6, 0, 0), '10.87', 7.29,
#        datetime.datetime(2023, 1, 11, 0, 0), '16.54', 11,
#        datetime.datetime(2023, 6, 9, 0, 0)], dtype=object)

# %%
from datetime import datetime

def conv_data(x):
  # Extract the day and month
  day = x.day
  month = x.month
  value = (13*10 + month)/10
  return value

conv_data(datetime(2023, 4, 13, 0, 0))
# Out:
# 13.4

# %%
# Function to apply to date values
def conv_data(x):
    if isinstance(x, datetime):
        if isinstance(x, str):
            x = datetime.strptime(x, '%Y-%m-%d')  # Convert string to datetime
        day = x.day
        month = x.month
        value = (day * 10 + month) / 10
        return value
    return x  # Return non-date values as is

# Apply the conv_data function only to date values in specific columns
date_columns = ['Glucoza bazală']  # List of columns to process
for col in date_columns:
    df[col] = df[col].apply(conv_data)

df['Glucoza bazală'] = df['Glucoza bazală'].astype(float)

# Display the updated DataFrame
df['Glucoza bazală'].unique()
# Out:
# array([ 7.03,  5.34,  6.26,  5.62,  8.82,  4.65,  7.31,  5.29,  5.82,
#         6.15,  6.02,  5.25,  5.66,  5.61,  8.  ,  4.32,  4.71,  4.59,
#         5.49,  5.02,  5.06,  4.9 ,  4.93,  5.43,  4.36,  5.37,  4.72,
#         4.78,  4.27,  4.96,  5.03,  4.97,  4.7 ,  5.78,  4.77,  7.5 ,
#         5.64,  6.2 ,  5.07,  4.54,  5.11,  4.23,  4.85,  5.63,  5.58,
#         5.81,   nan,  4.99,  5.3 ,  5.89,  6.44,  5.56,  5.08,  5.47,
#         5.14,  4.64,  6.45,  4.69,  4.19,  5.21,  4.81,  5.  ,  6.43,
#         4.89,  4.18,  7.59,  4.76,  4.98,  4.56,  6.05,  4.43,  5.15,
#         5.7 ,  4.91,  4.5 ,  5.39,  4.37,  4.46,  4.57,  6.42,  4.95,
#         4.68,  4.67,  5.75,  5.59,  5.97,  7.17,  5.09,  5.67,  4.74,
#         5.27,  5.36,  4.75,  6.78,  6.56,  6.52,  4.86,  5.22,  4.07,
#         5.35,  4.17,  5.41,  4.35,  4.94,  5.33,  4.41,  4.45,  5.79,
#         6.35,  4.24,  4.55,  4.44,  4.62,  4.84,  4.92,  4.49,  4.47,
#         4.61,  4.21, 72.  ,  5.26,  5.16,  3.83,  4.66,  4.48,  5.31,
#         4.2 ,  4.38,  5.54,  8.05,  3.93,  4.12,  4.58,  5.04,  5.4 ,
#         4.26,  4.31,  4.1 ,  5.46,  3.51,  6.06,  4.33,  4.83,  4.42,
#         4.13,  4.04,  5.1 ,  6.1 ,  5.6 ,  5.2 ,  5.9 ,  6.4 ,  4.8 ,
#         4.4 ,  4.6 ,  5.8 ,  5.5 ,  7.9 ,  4.3 ,  6.6 ,  7.4 ,  6.3 ,
#         6.  ,  6.5 ,  6.8 ,  8.2 ,  7.2 ,  4.  ,  3.8 ,  3.9 ,  3.6 ,
#         4.79,  5.01,  4.34,  4.39,  4.05,  6.64,  5.24,  6.7 , 14.5 ,
#         7.7 ,  7.  ,  5.48,  5.45,  3.2 ,  5.76, 11.4 ,  8.8 ,  8.6 ,
#        10.5 ,  8.5 , 10.8 , 18.9 ,  9.4 , 10.1 ,  9.3 , 13.6 , 18.2 ,
#        14.77,  7.23, 10.29,  6.51,  7.6 ,  7.53,  7.62, 13.15,  5.99,
#         8.22, 11.8 ,  8.1 ,  7.1 ,  7.16, 12.2 ,  8.83, 19.32,  9.51,
#        13.56,  6.21,  6.14, 13.4 , 11.7 , 11.9 ,  5.23, 12.3 ,  8.62,
#         7.78,  8.9 ,  9.2 , 15.6 ,  6.72, 12.4 ,  7.69,  8.7 , 10.87,
#         7.29, 11.1 , 16.54, 11.  ,  9.6 ])

# %%
df['Glucoza bazală'].isna().sum()
df['Glucoza bazală'] = df['Glucoza bazală'].replace([[72], [12]])

# %%
round(df.groupby(by='Sexul')['Glucoza bazală'].describe().T, 1)
# Out:
# Sexul      B      F
# count  341.0  677.0
# mean     6.0    5.2
# std      2.0    1.3
# min      3.2    3.5
# 25%      5.0    4.6
# 50%      5.4    5.0
# 75%      6.1    5.4
# max     18.9   19.3

# %%
scatter_2(subset=['Virsta, anii', 'Glucoza bazală'],
          x='Virsta, anii',
          y='Glucoza bazală',
          h='Sexul', col='Sexul')

# %%
df['Glucoza_cat'] = pd.cut(df['Glucoza bazală'],
                           [0, 5.59, 6.99, 100],
                           labels = ['norma', 'prediabetes', 'diabetes'])


round(df['Glucoza_cat'].value_counts(normalize=True), 2)
# Out:
# norma          0.73
# prediabetes    0.19
# diabetes       0.08
# Name: Glucoza_cat, dtype: float64

# %%
# Calculate proportions
gender_proportions = df['Glucoza_cat'].value_counts(normalize=True) * 100  # Multiply by 100 to get percentages

# Create a bar plot with proportions using Seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(6, 4))  # Optional: Set the figure size
ax = sns.barplot(x=gender_proportions.index, y=gender_proportions.values, palette="viridis")
ax.set(ylabel="Percentage", title="Diabetes status Distribution Glucose level")

# Display percentages on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center')

plt.ylim(0, 100)
file_path = f'/content/drive/MyDrive/DZ_endocrinologie/Diabetes by Glucose'
plt.savefig(file_path, dpi=dpi)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
import numpy as np



# Filter out rows with missing values
df_cleaned = df.dropna(subset=['Virsta, anii', 'Glucoza bazală', 'Glucoza_cat', 'IMC'])

# Create a relplot using Seaborn
g = sns.relplot(
    x='Virsta, anii',
    y='IMC',
    hue='Glucoza_cat',
    col='Glucoza_cat',
    row='Sexul',
    data=df_cleaned,
    height=3.5,
    kind='scatter'
)

# Calculate Spearman's correlation coefficient and 95% CI
for ax in g.axes.flat:
    # Get the 'Glucoza_cat' value from the column title
    glucoza_cat_value = ax.get_title()[26:]
    #print(glucoza_cat_value)

    # Get the 'Sexul' value from the row title
    sexul_value = ax.get_title()[8]
    #print(sexul_value)

    # Filter data for each subplot
    data_subset = df_cleaned[
        (df_cleaned['Glucoza_cat'] == glucoza_cat_value) &
        (df_cleaned['Sexul'] == sexul_value)
    ]

    correlation, p_value = spearmanr(data_subset['Virsta, anii'], data_subset['IMC'])

    # Bootstrap to calculate 95% CI for the correlation
    np.random.seed(0)  # Set a random seed for reproducibility
    n_iterations = 1000  # Number of bootstrap iterations
    bootstrap_correlations = []

    for _ in range(n_iterations):
        # Resample the data with replacement
        resampled_data = data_subset.sample(len(data_subset), replace=True)
        resampled_correlation, _ = spearmanr(resampled_data['Virsta, anii'], resampled_data['IMC'])
        bootstrap_correlations.append(resampled_correlation)

    # Calculate 95% CI
    lower_ci = np.percentile(bootstrap_correlations, 2.5)
    upper_ci = np.percentile(bootstrap_correlations, 97.5)

    # Annotate the correlation with 95% CI
    ax.annotate(
        f"Spearman's ρ = {correlation:.2f}\n95% CI: [{lower_ci:.2f}, {upper_ci:.2f}]",
        xy=(110, 170),
        xycoords='axes points',  # Adjust 'xycoords'
        fontsize=10,
        color='black',
        ha='right'
    )

    # Add an interpolation line with 95% CI using sns.regplot
    sns.regplot(
        x='Virsta, anii',
        y='IMC',
        data=data_subset,
        ax=ax,
        scatter=False,
        color='black',
        ci=95
    )
file_path = f'/content/drive/MyDrive/DZ_endocrinologie/Sexul-IMC-Virsta-Glucose status'
plt.savefig(file_path, dpi=dpi)
plt.show()

# %% [markdown]
# #Vârsta – sex – HBA1C

# %%
# Function to apply to date values
def conv_data(x):
    if isinstance(x, datetime):
        if isinstance(x, str):
            x = datetime.strptime(x, '%Y-%m-%d')  # Convert string to datetime
        day = x.day
        month = x.month
        value = (day * 10 + month) / 10
        return value
    return x  # Return non-date values as is

# Apply the conv_data function only to date values in specific columns
date_columns = ['HbA1C']  # List of columns to process
for col in date_columns:
    df[col] = df[col].apply(conv_data)


df['HbA1C'].replace(['?'], [np.NaN], inplace=True)
df['HbA1C'] = df['HbA1C'].astype(float)

# Display the updated DataFrame
df['HbA1C'].unique()
# Out:
# array([  nan,  5.56,  6.99,  6.08,  6.82,  5.68,  5.9 ,  5.55,  5.54,
#         5.29,  5.33,  5.59,  6.29,  5.18,  5.76,  5.83,  5.58,  5.57,
#         5.7 ,  5.84,  5.39,  6.72,  5.74,  5.48,  5.78,  5.36,  5.46,
#         4.95,  5.67,  5.53,  5.51,  5.73,  5.45,  5.23,  7.37,  5.22,
#         5.35,  6.06,  5.12,  5.52,  5.38,  5.32,  5.17,  5.87,  4.86,
#         5.82,  5.81,  8.1 ,  5.8 ,  5.85,  6.14,  6.88,  5.44,  5.1 ,
#         5.95,  5.92,  5.97,  6.  ,  5.65,  5.93,  5.5 ,  5.49,  5.41,
#         6.48,  6.27,  4.85,  5.88,  4.99,  6.86,  5.14,  5.69,  6.1 ,
#         6.4 ,  5.02,  5.94,  5.2 ,  5.77,  6.02,  6.05,  6.03,  5.16,
#         4.92,  5.25,  5.6 ,  5.4 ,  5.91,  5.79,  6.2 ,  5.3 ,  5.31,
#         4.89,  4.82,  5.75,  5.62,  5.05,  5.47,  6.12,  5.06,  5.09,
#         5.98,  6.21,  5.28,  5.99,  4.91,  5.01,  6.13, 10.2 ,  5.27,
#         6.09,  7.61,  7.42,  5.64,  5.61,  6.18,  6.28,  6.38,  5.72,
#         5.89,  7.21,  6.51,  6.39,  6.79,  6.19,  7.3 ,  6.23,  6.15,
#         6.8 ,  7.87,  5.96,  6.46,  6.7 ,  5.42,  4.87,  6.5 ,  6.37,
#         7.  ,  5.63,  5.71,  6.42,  6.3 ,  6.16,  5.86,  6.54,  7.1 ,
#        11.06,  7.14,  7.81,  8.97,  8.99,  7.22,  7.93,  6.78,  6.57,
#         8.42,  8.5 ,  6.62, 10.44, 10.69,  7.69, 11.18,  6.73,  6.81,
#         8.73,  8.78,  6.59,  6.77,  6.49, 10.27,  7.23,  8.34,  8.64,
#         7.76,  6.91,  7.98,  7.78, 12.73,  7.5 ,  6.97,  9.33, 11.42,
#         6.63,  9.65, 11.28,  9.35,  6.41,  6.25,  6.24,  6.17, 11.  ,
#         6.26,  6.87,  7.49,  8.63,  8.26,  7.73,  6.66,  7.85,  6.52,
#         8.8 ,  7.54,  8.79,  7.28,  8.43,  7.94, 11.3 ,  8.92,  8.76,
#         8.69])

# %%
round(df.groupby(by='Sexul')['HbA1C'].describe().T, 1)
# Out:
# Sexul      B      F
# count  176.0  249.0
# mean     6.4    6.0
# std      1.3    1.1
# min      4.8    4.8
# 25%      5.6    5.5
# 50%      6.0    5.8
# 75%      6.6    6.1
# max     11.3   12.7

# %%
scatter_2(subset=['Virsta, anii', 'HbA1C'],
          x='Virsta, anii',
          y='HbA1C',
          h='Sexul', col='Sexul')

# %%
df['HbA1C_cat'] = pd.cut(df['HbA1C'],
                           [0, 5.69, 6.49, 100],
                           labels = ['norma', 'prediabetes', 'diabetes'])


#≤ 5,69 % – norma;
#5,7 % – 6,49 % – prediabet;
#≥ 6,5 % - diabet

round(df['HbA1C_cat'].value_counts(normalize=True), 2)
# Out:
# prediabetes    0.40
# norma          0.39
# diabetes       0.21
# Name: HbA1C_cat, dtype: float64

# %%
# Calculate proportions
gender_proportions = df['HbA1C_cat'].value_counts(normalize=True) * 100  # Multiply by 100 to get percentages

# Create a bar plot with proportions using Seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(6, 4))  # Optional: Set the figure size
ax = sns.barplot(x=gender_proportions.index, y=gender_proportions.values, palette="viridis")
ax.set(ylabel="Percentage", title="Diabetes status Distribution by HbA1C_cat")

# Display percentages on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center')

plt.ylim(0, 100)
plt.show()

# %% [markdown]
# # Explanation is an systemic selection bias (HbA1C was sampled only for relative severe patients)

# %%
df['HbA1C_cat'].value_counts()
# Out:
# prediabetes    170
# norma          164
# diabetes        91
# Name: HbA1C_cat, dtype: int64

# %% [markdown]
# # Vârsta – sex – colesterol total

# %%
# Function to apply to date values
def conv_data(x):
    if isinstance(x, datetime):
        if isinstance(x, str):
            x = datetime.strptime(x, '%Y-%m-%d')  # Convert string to datetime
        day = x.day
        month = x.month
        value = (day * 10 + month) / 10
        return value
    return x  # Return non-date values as is

# Apply the conv_data function only to date values in specific columns
date_columns = ['Colesterol total']  # List of columns to process
for col in date_columns:
    df[col] = df[col].apply(conv_data)


df['Colesterol total'].replace(['-', '?'], [np.NaN, np.NaN], inplace=True)
df['Colesterol total'] = df['Colesterol total'].astype(float)

# Display the updated DataFrame
df['Colesterol total'].unique()
# Out:
# array([ 7.37,  5.06,  5.01,  6.11,  5.29,  5.27,  5.39,  5.71,  5.21,
#         5.15,  4.94,  4.54,  4.87,  7.02,  6.29,  5.64,  3.77,  5.61,
#         6.47,  5.08,  4.51,  3.94,  4.79,  4.56,  5.99,  5.04,  6.46,
#         4.76,  8.53,  6.26,  5.07,  4.32,  5.17,  6.37,  4.83,  5.68,
#         4.45,  6.89,  6.65,  4.59,  4.78,  5.12,  4.74,  3.32,  5.93,
#         5.73,  4.28,  5.69,  3.26,  6.71,  5.19,  5.53,  4.13,  5.9 ,
#         5.42,  6.2 ,  5.05,  4.48,  9.79,  5.4 ,  7.5 ,  6.52,  0.96,
#         7.52,  5.65,  6.66,  4.92,  7.73,  3.06,  6.84,  7.69,  4.  ,
#         5.1 ,  5.58,  6.62,  6.27,  4.3 ,  7.03,  5.79,  5.67,  5.16,
#         6.58,  3.6 ,  5.56,  6.57,  5.13,  5.86,  6.25,  4.49,  4.57,
#         4.27,  6.76,  6.06,  5.09,  4.99,  4.65,  4.21,  4.85,  7.49,
#         6.45,  5.49,  5.41,  6.4 ,  7.45,  4.68,  5.63,  7.04,  5.92,
#         3.81,  8.52,  5.26,  5.46,  4.08,  4.14,  5.94,  3.05,  4.67,
#         7.01,  5.7 ,  6.39,  4.2 ,  7.19,  3.87,  3.49,  7.36,  5.83,
#         5.72,  5.2 ,  5.97,  4.18,  5.44,  4.39,  4.17,  5.55,  4.44,
#         4.75,  5.28,  4.34,  5.57,  4.55,  3.44,  5.3 ,  6.56,  6.92,
#         4.58,  3.55,  6.15,  4.88,  5.02,  3.97,  3.71,  4.6 ,  7.85,
#         4.73,  6.36,  5.03,  3.79,  4.93,  5.48,  3.7 ,  6.63,  7.87,
#         9.19,  2.29,  4.43,  5.47,  4.86,  7.  ,  6.42,  6.14,  7.55,
#         5.  ,  6.48,  3.42,  7.24,  4.61,  6.93,  4.16,  5.33,  7.72,
#         3.73,  3.4 ,  6.07,  6.18,  3.98,  5.51,  5.32,  4.98,  4.69,
#         3.99,  8.01,  6.85,  7.63,  4.97,  7.48,  6.16,  6.55,  6.23,
#         6.53,  4.29,  9.53,  7.54,  4.02,  7.34,  4.05,  5.8 ,  6.44,
#         3.83,  4.19,  3.89,  6.02,  6.69,  4.96,  6.32,  6.75,  4.95,
#         7.4 ,  6.78,  4.25,  4.89,  5.88,  7.3 ,  6.12,  4.42,   nan,
#         5.54,  4.12,  6.59,  6.87,  5.22,  7.41,  6.  ,  5.75,  4.36,
#         4.26,  8.56,  6.64,  7.47,  5.25,  7.81,  5.37,  6.03,  5.89,
#         5.84,  4.91,  5.74,  5.85,  7.29,  7.68,  3.85,  7.26,  5.96,
#         6.28,  6.1 ,  7.51,  4.5 ,  4.35,  6.34,  8.83,  6.04,  6.21,
#         7.96,  5.11,  4.53,  7.06,  6.43,  7.18,  6.05,  3.92,  4.23,
#         7.08,  5.31,  4.66,  5.6 ,  4.64,  5.36,  6.82,  4.22,  7.94,
#         6.91,  6.09,  5.14,  5.95,  6.97,  8.39,  5.76,  8.79,  4.8 ,
#         6.35,  4.84,  3.9 ,  6.3 ,  7.39,  6.17, 11.36,  6.99,  4.07,
#         5.38,  6.33,  7.95,  7.67,  6.08,  4.33,  3.84,  6.61,  5.66,
#         4.52,  5.82,  3.41,  7.25,  7.53,  4.01,  7.46,  7.98,  7.16,
#         8.45,  5.62,  5.35,  5.18,  4.9 ,  6.54,  7.76,  7.83,  6.13,
#         6.94,  5.45,  7.56,  6.6 ,  5.34,  6.98,  5.5 ,  5.24,  7.33,
#         8.05,  6.68, 11.02,  7.93,  4.37,  6.7 ,  4.77,  6.38,  4.71,
#         7.79,  9.31,  1.38,  8.81,  5.98,  3.46,  4.81,  7.38,  3.72,
#         7.07,  8.14,  7.44,  6.86,  4.04,  4.41,  2.88,  6.51,  8.12,
#         7.32,  8.1 ,  6.5 ,  6.74,  7.61,  6.49,  8.87,  5.81,  7.09,
#         6.22,  3.76,  7.42,  8.15,  8.82,  4.03,  8.74,  5.77,  9.16,
#         4.38,  3.3 ,  3.36,  3.51,  7.75,  3.24,  6.41,  6.8 ,  4.4 ,
#         4.31,  3.22,  5.23,  7.2 ,  8.55,  6.72,  6.9 ,  7.9 ,  6.73,
#         6.96,  7.64,  5.43,  4.7 ,  6.67,  6.79,  8.  ,  4.62,  3.93,
#         3.38,  8.54,  4.24,  4.47,  5.91,  7.35,  8.49,  3.75,  7.71,
#         4.72,  3.8 ,  6.24,  8.7 ,  6.83,  7.65,  7.15])

# %%
round(df.groupby(by='Sexul')['Colesterol total'].describe().T, 1)
# Out:
# Sexul      B      F
# count  343.0  675.0
# mean     5.6    5.7
# std      1.1    1.2
# min      3.1    1.0
# 25%      4.8    4.8
# 50%      5.6    5.6
# 75%      6.4    6.4
# max      9.2   11.4

# %%
scatter_2(subset=['Virsta, anii', 'Colesterol total'],
          x='Virsta, anii',
          y='Colesterol total',
          h='Sexul', col='Sexul')

# %%
df['Colesterol total_cat'] = pd.cut(df['Colesterol total'],
                           [0, 5.19, 6.19, 100],
                           labels = ['normal', 'borderline', 'hight'])


#≤ 5,19;
#5,2 - 6,19;
#≥ 6,2


round(df['Colesterol total_cat'].value_counts(normalize=True), 2)
# Out:
# normal        0.37
# borderline    0.32
# hight         0.31
# Name: Colesterol total_cat, dtype: float64

# %%
df['Colesterol total_cat'].value_counts()
# Out:
# normal        378
# borderline    323
# hight         317
# Name: Colesterol total_cat, dtype: int64

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Calculate proportions
gender_proportions = df['Colesterol total_cat'].value_counts(normalize=True) * 100  # Multiply by 100 to get percentages

# Create a bar plot with proportions using Seaborn
sns.set(style="whitegrid")
plt.figure(figsize=(6, 4))  # Optional: Set the figure size
ax = sns.barplot(x=gender_proportions.index, y=gender_proportions.values, palette="viridis")
ax.set(ylabel="Percentage", title="Colesterol total Distribution")

# Display percentages on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center')

plt.ylim(0, 100)
plt.show()

# %%
round(df.groupby(by=['Sexul', 'Colesterol total_cat'])['Virsta, anii'].describe().T, 1)
# Out:
# Sexul                     B                        F
# Colesterol total_cat normal borderline  hight normal borderline  hight
# count                 127.0      110.0  106.0  251.0      213.0  211.0
# mean                   51.4       52.8   52.2   42.5       47.3   53.2
# std                    15.5       13.5   10.0   13.0       11.6    9.8
# min                    14.0       19.0   27.0   17.0       25.0   18.0
# 25%                    38.5       43.0   45.0   34.0       38.0   47.0
# 50%                    54.0       54.5   52.0   40.0       45.0   55.0
# 75%                    62.5       62.0   59.0   51.0       56.0   61.0
# max                    84.0       85.0   73.0   73.0       73.0   74.0

# %% [markdown]
# #vârsta – sex – ['LDL-C',  'VLDL Colesterol',  'HDL-C',  'Trigliceride ']

# %%
list(df.columns)
# Out:
# ['Virsta, anii',
#  'Sexul',
#  'Educația (ultimul nivel de educatie finalizat)',
#  'Starea civila',
#  'Grup etnic ',
#  'Ocupaţia (guvernam) de bază din ultimele 12 luni? [Angajat în sectorul guvernamental]',
#  'Ocupaţia (non guvvern de bază din ultimele 12 luni? [Angajat în sectorul non-guvernamental sau privat]',
#  'Ocupaţia (cont propr) de bază din ultimele 12 luni? [Angajat pe cont propriu]',
#  'Ocupaţia (student) de bază din ultimele 12 luni? [Student]',
#  'Ocupaţia (casnic) de bază din ultimele 12 luni? [Casnic/casnică]',
#  'Ocupaţia (pensionar) de bază din ultimele 12 luni? [Pensionar]',
#  'Ocupaţia (apt) de bază din ultimele 12 luni? [Neangajat în câmpul muncii (apt de muncă)]',
#  'Ocupaţia (inapt) de bază din ultimele 12 luni? [Neangajat în câmpul muncii (inapt de muncă)]',
#  'Ocupaţia (refuz) de bază din ultimele 12 luni? [Refuz]',
#  'Care sunt veniturile medii lunare (MDL) ale gospodăriei DVS în ultimele 12 luni?',
#  'Modul de viață',
#  'Fumatul',
#  'Fumatul  _ Câți ani*țigarete pe zi',
#  'Rudele de gradul 1 [Diabet zaharat]',
#  'Rudele de gradul 1 [HTA]',
#  'Rudele de gradul 1 [Obesitatea]',
#  'Rudele de gradul 1 [Dislipidemie]',
#  'Rudele de gradul 1 [Patologia glandei tiroide]',
#  'Rudele de gradul 2 [Diabet zaharat]',
#  'Rudele de gradul 2 [HTA]',
#  'Rudele de gradul 2 [Obesitatea]',
#  'Rudele de gradul 2 [Dislipidemie]',
#  'Rudele de gradul 2 [Patologia glandei tiroide]',
#  'Istotia personala [Diabet zaharat]',
#  'Istotia personala [HTA]',
#  'Istotia personala [Obesitatea]',
#  'Istotia personala [Dislipidemie]',
#  'Istotia personala [Patologia glandei tiroide]',
#  'Tratamentul curent  (Medicamente folosite actualmente)',
#  'Covid',
#  'Numarul de copii (intrebare pentru femei)',
#  'Numarul de copii cu masa corporala peste 4 kg la nastere (intrebare pentru femei)',
#  'De câte ori pe zi mâncați?',
#  'Într-o săptămână tipică, în câte zile mâncaţi fructe? (Numarul de zile)',
#  'Câte porţii de fructe mâncaţi pe parcursul unei din aceste zile? (Numărul de porții)',
#  'Într-o săptămână tipică, în câte zile mâncaţi legume (cu excepţia cartofilor)?Numărul de zile',
#  'Câte porţii de legume (cu excepţia cartofilor) mâncaţi pe parcursul unei din aceste zile? Numărul de porții',
#  'De câte ori pe săptămână consumați cereale?',
#  'De câte ori pe săptămână consumați cartofi?',
#  'Câte bucăți de pîine consumați pe zi?',
#  'De câte ori pe săptămână consumați turte, chifle, gofre?',
#  'Talia, cm',
#  'Greutatea, kg',
#  'IMC',
#  'Circumferinta abdominala, cm (CA)',
#  'Circumferinta Șoldului, cm (CS)',
#  'CA_CȘ',
#  'TA sist',
#  'TA diast',
#  'Glucoza bazală',
#  'Colesterol total',
#  'LDL-C',
#  'VLDL Colesterol',
#  'HDL-C',
#  'Trigliceride ',
#  'Acid uric',
#  'Creatinina',
#  'HbA1C',
#  'TSH',
#  'AC/TPO',
#  'Ca',
#  'TOTG (a jeun)',
#  'TOTG (peste 2 ore)',
#  'HOMA',
#  'Hb',
#  'Eritrocite',
#  'Chestionar Findrisc (valoare)',
#  'Chestionar Findrisc ',
#  'Chestionar Anxietate (valoare)',
#  'Chestionar Anxietate',
#  'Chestionar Depresie (valoare)',
#  'Chestionar Depresie',
#  'Chestionar evaluarea Stresului (valoare)',
#  'Chestionar evaluarea Stresului',
#  'Chestionar HADS: Depresia (valoare)',
#  'Chestionar HADS: Depresia',
#  'Chestionar HADS: Anxietatea (valoare)',
#  'Chestionar HADS: Anxietatea',
#  'Chestionar MMSE (disfuncții cognitive) valoarea',
#  'Chestionar MMSE (disfuncții cognitive)',
#  'eGFR',
#  'Insulina',
#  'Laborator',
#  'Risc cardiovascular',
#  'Risc CV global usor',
#  'Risc CV global moderat',
#  'Risc CV global crescut',
#  'Risc CV foarte crescut',
#  'Mediu de trai',
#  'Score 2       scazut',
#  'Score 2  moderat',
#  'Score 2 crescut',
#  'Glucoza_cat',
#  'HbA1C_cat',
#  'Colesterol total_cat']

# %%
# Function to apply to date values
def conv_data(x):
    if isinstance(x, datetime):
        if isinstance(x, str):
            x = datetime.strptime(x, '%Y-%m-%d')  # Convert string to datetime
        day = x.day
        month = x.month
        value = (day * 10 + month) / 10
        return value
    return x  # Return non-date values as is

# Apply the conv_data function only to date values in specific columns
date_columns = ['LDL-C', 'HDL-C',  'Trigliceride ']  # List of columns to process
for col in date_columns:
    print(col)
    print("_______________")
    df[col] = df[col].apply(conv_data)
    df[col].replace(['2,.15' , '-', '?'], ['2.15', np.NaN, np.NaN], inplace=True)
    df[col] = df[col].astype(float)
    print(df[col].unique())
# Out:
# LDL-C
# _______________
# [5.58 3.59 3.43 4.13 4.09 3.6  3.89 3.7  3.33 3.54 3.27 2.95 3.41 4.86
#  4.7  3.92 2.18 3.68 2.85 3.03 2.23 3.19 3.77 3.34 2.58 3.4  3.56 3.25
#  3.32 2.54 6.29 4.38 3.08 2.42 4.83 3.31 2.84 4.73 4.44 2.92 3.16 3.36
#  3.   3.07 1.8  4.25 4.01 2.78 4.14 1.9  3.46 3.81 2.46 2.27 3.52 4.23
#  2.82 7.71 3.61 5.88 4.41 3.74 3.73 5.84 3.87 4.64 3.14 5.56 1.02 5.29
#  5.85 2.13 3.35 3.9  4.89 3.72 2.33 5.1  4.04 4.21 4.17 2.75 2.02 3.47
#  4.55 5.05 3.88 4.5  4.71 4.87 3.12 3.28 4.65 4.54 3.39 3.99 3.64 3.11
#  3.42 4.75 3.8  3.66 4.56 4.77 4.11 5.19 2.36 6.62 2.37 2.55 2.34 4.33
#  1.1  3.23 5.54 2.63 5.6  2.17 4.42 2.51 5.04 3.63 3.5  4.02 3.84 4.
#  2.76 2.66 2.83 2.57 2.6  3.3  3.04 3.17 2.89 1.82 4.61 5.07 4.6  1.7
#  4.29 2.05 3.78 2.74 2.24 3.21 1.84 3.76 1.63 4.36  nan 3.15 2.32 4.63
#  5.74 3.45 6.88 2.94 2.3  2.9  3.98 5.16 4.19 4.28 2.49 5.93 3.13 4.8
#  1.73 2.99 4.78 2.41 2.71 3.51 5.62 3.57 1.98 3.02 4.32 3.83 5.15 3.91
#  2.73 4.16 2.29 3.01 1.86 5.22 5.41 2.61 3.09 4.49 4.08 3.26 6.18 4.95
#  4.66 2.2  3.2  3.53 4.06 2.79 2.22 3.44 3.48 3.22 2.87 4.34 2.52 3.94
#  2.45 2.69 3.69 4.03 3.65 3.86 2.5  4.84 4.43 3.49 2.64 4.35 3.06 2.96
#  4.9  4.31 3.58 2.53 5.37 3.37 4.1  4.05 5.21 5.24 2.01 4.62 5.06 4.51
#  2.93 3.62 4.26 5.9  3.85 5.14 2.98 4.74 4.47 3.55 2.38 1.95 3.1  2.81
#  3.18 4.2  5.42 5.66 3.29 4.3  3.75 3.79 1.42 4.72 4.79 7.74 2.48 2.25
#  3.93 2.65 2.28 4.82 2.44 4.96 5.44 4.53 4.98 5.8  2.77 2.7  3.95 5.34
#  2.1  4.68 4.18 5.17 2.07 5.65 2.91 4.48 5.38 4.67 3.67 2.35 5.13 7.56
#  6.71 2.67 2.68 2.86 5.5  6.48 4.81 6.41 1.75 5.02 2.04 3.71 5.33 4.88
#  5.08 3.24 5.18 3.97 4.52 2.43 2.12 1.72 5.39 5.26 5.3  5.2  2.97 5.87
#  2.72 5.01 2.19 4.97 5.98 3.96 4.37 2.56 5.91 1.64 1.85 5.7  2.   4.24
#  2.59 2.39 2.88 1.59 4.39 6.1  5.25 2.62 5.4  1.46 5.53 5.23 2.31 5.51
#  3.38 1.68 4.22 5.46 2.26 6.2  1.54]
# HDL-C
# _______________
# [1.48 1.29 0.83 1.75 1.   1.49 1.15 1.71 1.65 1.01 1.54 1.33 1.38 1.88
#  1.06 1.34 1.44 1.61 2.08 1.19 1.41 1.5  2.26 1.14 2.32 1.1  1.37 1.92
#  0.94 1.68 1.72 1.24 1.13 1.86 0.98 1.45 1.36 1.39 0.77 1.43 3.   1.25
#  1.17 1.28 1.23 1.04 0.71 0.89 1.02 0.96 1.22 1.08 1.3  1.09 1.51 1.96
#  1.03 2.05 1.47 1.32 1.11 0.87 1.35 2.14 1.59 1.12 0.8  1.84 1.53 1.46
#  0.99 2.35 1.76 1.77 1.18 2.43 1.05 2.02 1.2  1.69 0.95 1.64 2.19 1.62
#  1.66 1.82 1.63 1.81 2.15 2.11 1.31 0.86 1.94 1.42 2.17 1.26 2.85 1.21
#  1.55 1.97 1.4  1.78 1.74 1.57 2.07 1.8  2.59 1.27 2.06 3.01 1.7  1.95
#  0.91 0.97 2.48 1.07 1.99 2.62 1.83 0.9  0.88 1.79 1.93 1.67 1.87 1.58
#  2.37 2.47 1.9  2.   1.52 2.3  2.66 1.89 2.21 2.2  1.6  1.98 2.13 0.93
#  2.01 1.85 2.39 2.09 0.39 2.29 1.56 2.24  nan 2.22 1.16 2.28 0.79 1.73
#  2.18 2.53 0.78 0.73 2.92 2.03 2.12 0.82 2.8  2.1  2.44 2.16 2.5  2.04
#  0.84 0.92 0.26 0.75 2.49]
# Trigliceride
# _______________
# [ 1.76  0.96  1.97  1.5   1.14  1.06  0.95  1.12  1.54  3.13  1.09  1.04
#   0.82  1.24  2.28  1.65  0.57  1.2   1.32  0.87  1.18  0.8   1.07  0.78
#   1.47  1.25  1.1   1.87  3.38  0.52  0.6   2.7   0.83  1.45  2.42  1.27
#   1.22  1.31  1.71  2.36  0.79  2.94  0.62  0.48  0.84  1.86  1.94  1.92
#   0.44  8.41  0.99  0.74  1.95  1.11  0.9   1.4   3.57  1.88  1.64  1.46
#   1.68  2.65  1.61  2.71  4.43  1.96  1.75  1.15  2.1   1.28  2.02  1.66
#   0.89  2.06  0.68  4.67  1.02  0.72  1.3   1.21  1.73  0.69  1.91  2.24
#   1.    0.94  0.76  2.26  1.82  1.56  2.57  1.48  0.88  1.26  1.69  0.93
#   0.51  0.61  0.66  1.08  0.38  1.34  1.59  2.3   2.52  0.75  3.03  0.77
#   1.42  1.03  0.63  1.01  0.59  2.54  0.41  0.73  2.16  0.54  0.71  0.46
#   0.85  1.58  0.42  0.47  0.81  1.33  0.65  1.99  0.98  1.29  2.73  2.21
#   1.13  2.09  2.4   1.39  2.04  2.18  1.36  1.38  3.92  1.23  0.7   1.7
#   2.46   nan  3.8   2.61  1.74  0.86  1.19  1.16  0.4   0.91  1.41  3.26
#   2.62  0.58  6.87  3.68  0.31  2.17  1.63  2.41  2.47  1.84  1.57  1.6
#   3.1   1.9   1.05  1.35  2.05  2.66  2.5   2.49  0.97  1.81  0.64  0.53
#   2.12  2.11  0.67  1.51  2.01  3.11  1.53  0.55  1.62  3.43  1.67  0.45
#   0.2   1.17  2.58  0.43  0.56  0.92  1.83  1.78  2.33  5.02  2.15  0.39
#   0.28  1.79  3.45  5.34  0.03  2.23  0.49  2.37  2.44  1.44  0.5   3.7
#   2.67  1.8   0.23  2.48  1.55  2.95  2.72  4.54  2.84  2.81  2.07  2.8
#   2.19  2.96  4.07  2.45  0.36  2.2   1.98  4.4   2.91  2.78  1.77  2.76
#   4.28  4.44  3.79  1.49 12.21  2.31  3.47  2.63  1.52  3.72  1.89  2.
#   1.37  3.56  7.56  2.77  5.96  2.92  2.39  5.73  3.84  4.26  3.48  2.53
#   4.85  3.74  2.32  4.68  3.89  2.9   4.83  2.74  5.84  2.79  2.89  4.49
#   2.51]

# %%
df['Non-HDL-colesterol'] = df['Colesterol total'] - df['HDL-C']

# %%
for el in ['LDL-C',  'Non-HDL-colesterol',  'HDL-C',  'Trigliceride ']:
  print(el)
  print("_____________________________________________")
  print(round(df.groupby(by='Sexul')['Colesterol total'].describe().T, 1))
  print("_____________________________________________")
# Out:
# LDL-C
# _____________________________________________
# Sexul      B      F
# count  343.0  675.0
# mean     5.6    5.7
# std      1.1    1.2
# min      3.1    1.0
# 25%      4.8    4.8
# 50%      5.6    5.6
# 75%      6.4    6.4
# max      9.2   11.4
# _____________________________________________
# Non-HDL-colesterol
# _____________________________________________
# Sexul      B      F
# count  343.0  675.0
# mean     5.6    5.7
# std      1.1    1.2
# min      3.1    1.0
# 25%      4.8    4.8
# 50%      5.6    5.6
# 75%      6.4    6.4
# max      9.2   11.4
# _____________________________________________
# HDL-C
# _____________________________________________
# Sexul      B      F
# count  343.0  675.0
# mean     5.6    5.7
# std      1.1    1.2
# min      3.1    1.0
# 25%      4.8    4.8
# 50%      5.6    5.6
# 75%      6.4    6.4
# max      9.2   11.4
# _____________________________________________
# Trigliceride
# _____________________________________________
# Sexul      B      F
# count  343.0  675.0
# mean     5.6    5.7
# std      1.1    1.2
# min      3.1    1.0
# 25%      4.8    4.8
# 50%      5.6    5.6
# 75%      6.4    6.4
# max      9.2   11.4
# _____________________________________________

# %%
for el in ['LDL-C',  'Non-HDL-colesterol',  'HDL-C',  'Trigliceride ']:
  scatter_2(subset=['Virsta, anii', el],
            x='Virsta, anii',
            y=el,
            h='Sexul', col='Sexul')

# %%
def var_cut (df, var, levels, labels):
   var_cat=var+'cat'
   df[var_cat] = pd.cut(df[var], levels, labels=labels)

   print(round(df[var_cat].value_counts(normalize=True), 2))

   # Calculate proportions
   proportions = df[var_cat].value_counts(normalize=True) * 100  # Multiply by 100 to get percentages

   # Create a bar plot with proportions using Seaborn
   sns.set(style="whitegrid")
   plt.figure(figsize=(6, 4))  # Optional: Set the figure size
   ax = sns.barplot(x=proportions.index, y=proportions.values, palette="viridis")
   ax.set(ylabel="Percentage", title=f"{var_cat} Distribution")



   # Display percentages on top of the bars
   for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}%', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center')

   plt.ylim(0, 100)

   file_path = f'/content/drive/MyDrive/DZ_endocrinologie/{var_cat}'
   plt.savefig(file_path, dpi=dpi)

   plt.show()




var_cut(df, 'Colesterol total', [0, 5.19, 6.19, 100], ['normal', 'borderline', 'hight'])
# Out:
# normal        0.37
# borderline    0.32
# hight         0.31
# Name: Colesterol totalcat, dtype: float64

# %%
for el in [['LDL-C', [0, 2.6, 3.39, 4, 4.89, 100], [1, 2, 3, 4, 5]],
           #['Non-HDL-colesterol', [], []],
           #['HDL-C', [], []],
           ['Trigliceride ', [0, 1.7, 2.29, 100], ['normal', 'borderline', 'hight']]]:


  var_cut(df, var=el[0], levels=el[1], labels=el[2])
# Out:
# 2    0.29
# 3    0.26
# 4    0.22
# 1    0.14
# 5    0.09
# Name: LDL-Ccat, dtype: float64
# normal        0.75
# borderline    0.13
# hight         0.12
# Name: Trigliceride cat, dtype: float64

# %% [markdown]
# #Feature engineering

# %%
list(df.columns)
# Out:
# ['Virsta, anii',
#  'Sexul',
#  'Educația (ultimul nivel de educatie finalizat)',
#  'Starea civila',
#  'Grup etnic ',
#  'Ocupaţia (guvernam) de bază din ultimele 12 luni? [Angajat în sectorul guvernamental]',
#  'Ocupaţia (non guvvern de bază din ultimele 12 luni? [Angajat în sectorul non-guvernamental sau privat]',
#  'Ocupaţia (cont propr) de bază din ultimele 12 luni? [Angajat pe cont propriu]',
#  'Ocupaţia (student) de bază din ultimele 12 luni? [Student]',
#  'Ocupaţia (casnic) de bază din ultimele 12 luni? [Casnic/casnică]',
#  'Ocupaţia (pensionar) de bază din ultimele 12 luni? [Pensionar]',
#  'Ocupaţia (apt) de bază din ultimele 12 luni? [Neangajat în câmpul muncii (apt de muncă)]',
#  'Ocupaţia (inapt) de bază din ultimele 12 luni? [Neangajat în câmpul muncii (inapt de muncă)]',
#  'Ocupaţia (refuz) de bază din ultimele 12 luni? [Refuz]',
#  'Care sunt veniturile medii lunare (MDL) ale gospodăriei DVS în ultimele 12 luni?',
#  'Modul de viață',
#  'Fumatul',
#  'Fumatul  _ Câți ani*țigarete pe zi',
#  'Rudele de gradul 1 [Diabet zaharat]',
#  'Rudele de gradul 1 [HTA]',
#  'Rudele de gradul 1 [Obesitatea]',
#  'Rudele de gradul 1 [Dislipidemie]',
#  'Rudele de gradul 1 [Patologia glandei tiroide]',
#  'Rudele de gradul 2 [Diabet zaharat]',
#  'Rudele de gradul 2 [HTA]',
#  'Rudele de gradul 2 [Obesitatea]',
#  'Rudele de gradul 2 [Dislipidemie]',
#  'Rudele de gradul 2 [Patologia glandei tiroide]',
#  'Istotia personala [Diabet zaharat]',
#  'Istotia personala [HTA]',
#  'Istotia personala [Obesitatea]',
#  'Istotia personala [Dislipidemie]',
#  'Istotia personala [Patologia glandei tiroide]',
#  'Tratamentul curent  (Medicamente folosite actualmente)',
#  'Covid',
#  'Numarul de copii (intrebare pentru femei)',
#  'Numarul de copii cu masa corporala peste 4 kg la nastere (intrebare pentru femei)',
#  'De câte ori pe zi mâncați?',
#  'Într-o săptămână tipică, în câte zile mâncaţi fructe? (Numarul de zile)',
#  'Câte porţii de fructe mâncaţi pe parcursul unei din aceste zile? (Numărul de porții)',
#  'Într-o săptămână tipică, în câte zile mâncaţi legume (cu excepţia cartofilor)?Numărul de zile',
#  'Câte porţii de legume (cu excepţia cartofilor) mâncaţi pe parcursul unei din aceste zile? Numărul de porții',
#  'De câte ori pe săptămână consumați cereale?',
#  'De câte ori pe săptămână consumați cartofi?',
#  'Câte bucăți de pîine consumați pe zi?',
#  'De câte ori pe săptămână consumați turte, chifle, gofre?',
#  'Talia, cm',
#  'Greutatea, kg',
#  'IMC',
#  'Circumferinta abdominala, cm (CA)',
#  'Circumferinta Șoldului, cm (CS)',
#  'CA_CȘ',
#  'TA sist',
#  'TA diast',
#  'Glucoza bazală',
#  'Colesterol total',
#  'LDL-C',
#  'VLDL Colesterol',
#  'HDL-C',
#  'Trigliceride ',
#  'Acid uric',
#  'Creatinina',
#  'HbA1C',
#  'TSH',
#  'AC/TPO',
#  'Ca',
#  'TOTG (a jeun)',
#  'TOTG (peste 2 ore)',
#  'HOMA',
#  'Hb',
#  'Eritrocite',
#  'Chestionar Findrisc (valoare)',
#  'Chestionar Findrisc ',
#  'Chestionar Anxietate (valoare)',
#  'Chestionar Anxietate',
#  'Chestionar Depresie (valoare)',
#  'Chestionar Depresie',
#  'Chestionar evaluarea Stresului (valoare)',
#  'Chestionar evaluarea Stresului',
#  'Chestionar HADS: Depresia (valoare)',
#  'Chestionar HADS: Depresia',
#  'Chestionar HADS: Anxietatea (valoare)',
#  'Chestionar HADS: Anxietatea',
#  'Chestionar MMSE (disfuncții cognitive) valoarea',
#  'Chestionar MMSE (disfuncții cognitive)',
#  'eGFR',
#  'Insulina',
#  'Laborator',
#  'Risc cardiovascular',
#  'Risc CV global usor',
#  'Risc CV global moderat',
#  'Risc CV global crescut',
#  'Risc CV foarte crescut',
#  'Mediu de trai',
#  'Score 2       scazut',
#  'Score 2  moderat',
#  'Score 2 crescut',
#  'Glucoza_cat',
#  'HbA1C_cat',
#  'Colesterol total_cat',
#  'Colesterol totalcat',
#  'Non-HDL-colesterol',
#  'LDL-Ccat',
#  'Trigliceride cat']

# %%
#HOMA: (Insulina x glucoza)/22,5   [datele din excell]
#Non-HDL-colesterol: total colesterol – HDL-colesterol
#Trigliceride mg/dl: trigliceride în mmol/l x 88,57 = mg/dl
#Glucoza în mg/dl: glucoza în mmol/l x 18,0182 = mg/dl
#Tyg index: triglyceride în mg/dl x glucoza în mg/dl
#Cholesterol ratio: cholesterol total / HDL-colesterol

df['HOMA'].isna().sum()

df.Insulina.isna().sum()
# Out:
# 208
